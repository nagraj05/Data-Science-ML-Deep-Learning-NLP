# %%
print("Hello")
# Out:
# Hello

# %%
a = 100
print(a)
# Out:
# 100

# %%
## Declaring and Assigning Variables
age=29
number=1.2
name="Nagraj"
is_Friend = True

print("age: ", age)
print("number:", number)
print("name: ", name)
print("is a Friend:", is_Friend)
# Out:
# age:  29
# number: 1.2
# name:  Nagraj
# is a Friend: True

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or with an _ and contain letter, numbers and underscores in between
## Variable names are case sensitive

## valid variable names

frst_name = "Nagraj "

# %%
## Understanding variable types
## python is dynamically typed, means type of a variable is determined at runtime.
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
## Type checking and conversion
age = 26
print(type(age))

# type Conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 26
# <class 'str'>

# %%
number = 2.11
int(number)
# Out:
# 2

# %%
float(number)
# Out:
# 2.11

# %%
float(int(number))
# Out:
# 2.0

# %%
#Dynamic Typing
## Python allows the type of a variable to change as the program executes
var=10
print(var, type(var))

var = "Hello"
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
